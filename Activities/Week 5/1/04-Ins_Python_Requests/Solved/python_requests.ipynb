# %% [markdown]
# # Instructor Do: Python Requests

# %%
# Initial imports
import requests

# %% [markdown]
# ## Define the request URL

# %%
# Create variable to hold request url
url = "http://api.worldbank.org/v2/country/ca/indicator/NY.GDP.MKTP.CD"

# %%
# Add format specifier to request url
url = url + "?format=json"

# %% [markdown]
# ## Execute GET request with URL

# %%
# Execute GET request
requests.get(url)
# Out:
# <Response [200]>

# %% [markdown]
# ## Store response as variable

# %%
# Execute GET request and store response
response_data = requests.get(url)

# %% [markdown]
# ## Retrieve API output using `content` attribute

# %%
# Get content
response_content = response_data.content
print(response_content)
# Out:
# b'[{"page":1,"pages":2,"per_page":50,"total":60,"sourceid":"2","lastupdated":"2020-04-09"},[{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2019","value":null,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2018","value":1713341704877.01,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2017","value":1646867220617.47,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2016","value":1526705529135.32,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2015","value":1552899925233.71,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2014","value":1801480123070.82,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2013","value":1842018420853.1,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2012","value":1823966686523.63,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2011","value":1789140665202.84,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2010","value":1613542812589.39,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2009","value":1371153004986.44,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2008","value":1549131208997.19,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2007","value":1464977190205.75,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2006","value":1315415197461.21,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2005","value":1169357979864.66,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2004","value":1023196771714.07,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2003","value":892382413817.715,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2002","value":757950678646.53,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.MKTP.CD","value":"GDP (current US$)"},"country":{"id":"CA","value":"Canada"},"countryiso3code":"CAN","date":"2001","value":736379777892.562,"unit":"","obs_status":"","decimal":0},{"indica ...

# %% [markdown]
# ## Use `json` function from `json` library to format

# %%
# Import json library
import json

# %%
# Format data as a raw json file
data = response_data.json()
print(data)
# Out:
# [{'page': 1, 'pages': 2, 'per_page': 50, 'total': 60, 'sourceid': '2', 'lastupdated': '2020-04-09'}, [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2019', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2018', 'value': 1713341704877.01, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2017', 'value': 1646867220617.47, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2016', 'value': 1526705529135.32, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2015', 'value': 1552899925233.71, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2014', 'value': 1801480123070.82, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2013', 'value': 1842018420853.1, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2012', 'value': 1823966686523.63, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2011', 'value': 1789140665202.84, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2010', 'value': 1613542812589.39, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2009', 'value': 1371153004986.44, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2008', 'value': 1549131208997.19, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2007', 'value': 1464977190205.75, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2006', 'value': 1315415197461.21, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2005', 'value': 1169357979864.66, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2004', 'value': 1023196771714.07, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'CA', 'value': 'Canada'}, 'countryiso3code': 'CAN', 'date': '2003', 'value': 892382413817.715, 'unit': '', 'obs_status': '', 'decimal': 0}, {'indicator': {'id': 'NY.GDP.MKTP.C ...

# %% [markdown]
# ## Format JSON with indents

# %%
# Add indents to JSON and output to screen
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "page": 1,
#         "pages": 2,
#         "per_page": 50,
#         "total": 60,
#         "sourceid": "2",
#         "lastupdated": "2020-04-09"
#     },
#     [
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2019",
#             "value": null,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2018",
#             "value": 1713341704877.01,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2017",
#             "value": 1646867220617.47,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2016",
#             "value": 1526705529135.32,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2015",
#             "value": 1552899925233.71,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2014",
#             "value": 1801480123070.82,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2013",
#             "value": 1842018420853.1,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2012",
#             "value": 1823966686523.63,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2011",
#             "value": 1789140665202.84,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2010",
#             "value": 1613542812589.39,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2009",
#             "value": 1371153004986.44,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2008",
#             "value": 1549131208997.19,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2007",
#             "value": 1464977190205.75,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2006",
#             "value": 1315415197461.21,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2005",
#             "value": 1169357979864.66,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2004",
#             "value": 1023196771714.07,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2003",
#             "value": 892382413817.715,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2002",
#             "value": 757950678646.53,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2001",
#             "value": 736379777892.562,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "2000",
#             "value": 742295468318.632,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1999",
#             "value": 676084000807.7,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1998",
#             "value": 631813279406.808,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1997",
#             "value": 652823920265.781,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1996",
#             "value": 628546387972.131,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1995",
#             "value": 604031623433.401,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1994",
#             "value": 578139279437.61,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1993",
#             "value": 577170761956.438,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1992",
#             "value": 592387689252.916,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1991",
#             "value": 610328183643.188,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1990",
#             "value": 593929550908.468,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1989",
#             "value": 565055743243.243,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1988",
#             "value": 507354351182.254,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1987",
#             "value": 431316742081.448,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1986",
#             "value": 377437927311.983,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1985",
#             "value": 364756499450.751,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1984",
#             "value": 355372558103.621,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1983",
#             "value": 340547711781.889,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1982",
#             "value": 313506525087.136,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1981",
#             "value": 306214863624.99,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1980",
#             "value": 273853826377.01,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1979",
#             "value": 243072102185.419,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1978",
#             "value": 218632867449.812,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1977",
#             "value": 211612156934.65,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1976",
#             "value": 206575564401.623,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1975",
#             "value": 173834029787.652,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1974",
#             "value": 160408697648.262,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1973",
#             "value": 131321859214.079,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1972",
#             "value": 113082820992.019,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1971",
#             "value": 99271961477.5203,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         },
#         {
#             "indicator": {
#                 "id": "NY.GDP.MKTP.CD",
#                 "value": "GDP (current US$)"
#             },
#             "country": {
#                 "id": "CA",
#                 "value": "Canada"
#             },
#             "countryiso3code": "CAN",
#             "date": "1970",
#             "value": 87896095224.4234,
#             "unit": "",
#             "obs_status": "",
#             "decimal": 0
#         }
#     ]
# ]

# %% [markdown]
# ## Identify country and GDP value second row

# %%
# Select country and GDP value for second row
country = data[1][1]["country"]["value"]
gdp_value = data[1][1]["value"]

print("Country: " + country)
print("GDP Value: " + str(gdp_value))
# Out:
# Country: Canada
# GDP Value: 1713341704877.01
